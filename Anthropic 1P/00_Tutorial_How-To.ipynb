# %% [markdown]
# # Tutorial How-To
#
# This tutorial **requires an API key** for interaction. If you don't have an API key, you can sign up for one via the [Anthropic Console](https://console.anthropic.com/) or view our [static tutorial answer key](https://docs.google.com/spreadsheets/u/0/d/1jIxjzUWG-6xBVIa2ay6yDpLyeuOh_hR_ZB75a47KX_E/edit) instead.

# %% [markdown]
# ## How to get started
#
# 1. Clone this repository to your local machine.
#
# 2. Install the required dependencies by running the following command:

# %%
# !pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.104.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from anthropic) (4.13.0)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Using cached docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from anthropic) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.15.0-cp314-cp314-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting sniffio (from anthropic)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.16)
# Requirement already satisfied: certifi in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/antilles/development/prompt-eng-interactive-tutorial/venv/lib64/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached pydantic_core-2.46.4-cp314-cp314-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.104.1-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.0/833.0 kB 5.4 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading jiter-0.15.0-cp314-cp314-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp314-cp314-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, jiter, docstring-parser, distro, annotated-types, pydantic, anthropic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [anthropic]/9 [anthropic]
# Successfully installed annotated-types-0.7.0 anthropic-0.104.1 distro-1.9.0 docstring-parser-0.18.0 jiter-0.15.0 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 typing-inspection-0.4.2

# %% [markdown]
# 3. Set up your API key and model name. Replace `"your_api_key_here"` with your actual Anthropic API key.

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")
MODEL_NAME = os.getenv("MODEL_NAME")  # nothing secret about this... just putting it in .env

# Stores the API_KEY & MODEL_NAME variables for use across notebooks within the IPython store
# %store API_KEY
# %store MODEL_NAME
# Out:
# Stored 'API_KEY' (str)
# Stored 'MODEL_NAME' (str)

# %% [markdown]
# 4. Run the notebook cells in order, following the instructions provided.

# %% [markdown]
# ---
#
# ## Usage Notes & Tips 💡
#
# - This course uses Claude 3 Haiku with temperature 0. We will talk more about temperature later in the course. For now, it's enough to understand that these settings yield more deterministic results. All prompt engineering techniques in this course also apply to previous generation legacy Claude models such as Claude 2 and Claude Instant 1.2.
#
# - You can use `Shift + Enter` to execute the cell and move to the next one.
#
# - When you reach the bottom of a tutorial page, navigate to the next numbered file in the folder, or to the next numbered folder if you're finished with the content within that chapter file.
#
# ### The Anthropic SDK & the Messages API
# We will be using the [Anthropic python SDK](https://docs.anthropic.com/claude/reference/client-sdks) and the [Messages API](https://docs.anthropic.com/claude/reference/messages_post) throughout this tutorial.
#
# Below is an example of what running a prompt will look like in this tutorial. First, we create `get_completion`, which is a helper function that sends a prompt to Claude and returns Claude's generated response. Run that cell now.

# %%
import anthropic

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# Now we will write out an example prompt for Claude and print Claude's output by running our `get_completion` helper function. Running the cell below will print out a response from Claude beneath it.
#
# Feel free to play around with the prompt string to elicit different responses from Claude.

# %%
# Prompt
prompt = "Hello, Claude!"

# Get Claude's response
print(get_completion(prompt))
# Out:
# Hello! It's nice to meet you. How can I help you today?

# %% [markdown]
# The `API_KEY` and `MODEL_NAME` variables defined earlier will be used throughout the tutorial. Just make sure to run the cells for each tutorial page from top to bottom.
